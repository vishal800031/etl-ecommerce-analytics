-- %%
CREATE TABLE ecommerce_analytics.data_warehouse.dim_customers(
    customer_id BIGINT,
    customer_name STRING
);

INSERT INTO ecommerce_analytics.data_warehouse.dim_customers 
select 
customer_id,
customer_name
from batch_1.data.customers
